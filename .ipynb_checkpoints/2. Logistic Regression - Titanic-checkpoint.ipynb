# %%
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('train.csv')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
def plot_bar(column):
    table = pd.DataFrame()
    table['Survived'] = df[df['Survived'] == 1][column].value_counts()
    table['Not Survived'] = df[df['Survived'] == 0][column].value_counts()
    table.plot(kind = 'bar')
    plt.xlabel(f'{column}')
    plt.ylabel('Number of Clients')
    plt.title('Distribution of {} and survival'.format(column))
    plt.show()

# %%
plot_bar('Pclass'),plot_bar('Sex'),plot_bar('SibSp')
# Out:
# (None, None, None)

# %%
df[['Pclass','Survived']].groupby(['Pclass'], as_index = False).mean().sort_values(by='Survived', ascending = False)
# Out:
#    Pclass  Survived
# 0       1  0.629630
# 1       2  0.472826
# 2       3  0.242363

# %%
df[['Sex','Survived']].groupby(['Sex'], as_index = False).mean().sort_values(by='Survived', ascending = False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
df[['SibSp','Survived']].groupby(['SibSp'], as_index = False).mean().sort_values(by='Survived', ascending = False)
# Out:
#    SibSp  Survived
# 1      1  0.535885
# 2      2  0.464286
# 0      0  0.345395
# 3      3  0.250000
# 4      4  0.166667
# 5      5  0.000000
# 6      8  0.000000

# %%
df.drop(['Ticket', 'Cabin'], axis = 1, inplace = True)

# %%
df.drop('Name', axis = 1, inplace =True)

# %%
df.drop('PassengerId', axis = 1, inplace =True)

# %%
df['Sex'] = df['Sex'].map({'female': 1, 'male': 0}).astype('int')

# %%
guess_ages = np.zeros((2,3))
guess_ages
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
for i in range(0, 2):
    for j in range(0, 3):
        guess_df = df[(df['Sex'] == i) & \
                                  (df['Pclass'] == j+1)]['Age'].dropna()
        
        age_guess = guess_df.median()        
        guess_ages[i,j] = int( age_guess/0.5 + 0.5 ) * 0.5

# %%
for i in range(0, 2):
    for j in range(0, 3):
        guess_df = df[(df['Sex'] == i) & \
                                  (df['Pclass'] == j+1)]['Age'].dropna()

        # age_mean = guess_df.mean()
        # age_std = guess_df.std()
        # age_guess = rnd.uniform(age_mean - age_std, age_mean + age_std)

        age_guess = guess_df.median()

        # Convert random age float to nearest .5 age
        guess_ages[i,j] = int( age_guess/0.5 + 0.5 ) * 0.5
            
for i in range(0, 2):
    for j in range(0, 3):
        df.loc[ (df.Age.isnull()) & (df.Sex == i) & (df.Pclass == j+1),\
                'Age'] = guess_ages[i,j]

df['Age'] = df['Age'].astype(int)

df.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked
# 0         0       3    0   22      1      0   7.2500        S
# 1         1       1    1   38      1      0  71.2833        C
# 2         1       3    1   26      0      0   7.9250        S
# 3         1       1    1   35      1      0  53.1000        S
# 4         0       3    0   35      0      0   8.0500        S

# %%
df['AgeBand'] = pd.cut(df['Age'], 5)
df[['AgeBand', 'Survived']].groupby(['AgeBand'], as_index=False).mean().sort_values(by='AgeBand', ascending=True)
# Out:
#          AgeBand  Survived
# 0  (-0.08, 16.0]  0.550000
# 1   (16.0, 32.0]  0.337374
# 2   (32.0, 48.0]  0.412037
# 3   (48.0, 64.0]  0.434783
# 4   (64.0, 80.0]  0.090909

# %%
df.loc[ df['Age'] <= 16, 'Age'] = 0
df.loc[(df['Age'] > 16) & (df['Age'] <= 32), 'Age'] = 1
df.loc[(df['Age'] > 32) & (df['Age'] <= 48), 'Age'] = 2
df.loc[(df['Age'] > 48) & (df['Age'] <= 64), 'Age'] = 3
df.loc[ df['Age'] > 64, 'Age'] = 4
df.head()
# Out:
#    Survived  Pclass  Sex  Age  SibSp  Parch     Fare Embarked       AgeBand
# 0         0       3    0    1      1      0   7.2500        S  (16.0, 32.0]
# 1         1       1    1    2      1      0  71.2833        C  (32.0, 48.0]
# 2         1       3    1    1      0      0   7.9250        S  (16.0, 32.0]
# 3         1       1    1    2      1      0  53.1000        S  (32.0, 48.0]
# 4         0       3    0    2      0      0   8.0500        S  (32.0, 48.0]

# %%
df = df.drop(['AgeBand'], axis=1)

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1
df[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#    FamilySize  Survived
# 3           4  0.724138
# 2           3  0.578431
# 1           2  0.552795
# 6           7  0.333333
# 0           1  0.303538
# 4           5  0.200000
# 5           6  0.136364
# 7           8  0.000000
# 8          11  0.000000

# %%
df['IsNotAlone'] = 1
df.loc[df['FamilySize'] == 1, 'IsNotAlone'] = 0

df[['IsNotAlone', 'Survived']].groupby(['IsNotAlone'], as_index=False).mean()
# Out:
#    IsNotAlone  Survived
# 0           0  0.303538
# 1           1  0.505650

# %%
df = df.drop(['Parch', 'SibSp', 'FamilySize'], axis=1)
df.head()
# Out:
#    Survived  Pclass  Sex  Age     Fare Embarked  IsNotAlone
# 0         0       3    0    1   7.2500        S           1
# 1         1       1    1    2  71.2833        C           1
# 2         1       3    1    1   7.9250        S           0
# 3         1       1    1    2  53.1000        S           1
# 4         0       3    0    2   8.0500        S           0

# %%
train_df.isnull().sum()
# Out:
# Survived     0
# Pclass       0
# Sex          0
# Age          0
# Fare         0
# Embarked     2
# Title        0
# IsAlone      0
# Age*Class    0
# dtype: int64

# %%
freq_port = df.Embarked.dropna().mode()[0]
freq_port
# Out:
# 'S'

# %%
df['Embarked'] = df['Embarked'].fillna(freq_port)
    
df[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %%
df['Embarked'] = df['Embarked'].map( {'S': 0, 'C': 1, 'Q': 2} ).astype(int)
df.head()
# Out:
#    Survived  Pclass  Sex  Age     Fare  Embarked  IsNotAlone
# 0         0       3    0    1   7.2500         0           1
# 1         1       1    1    2  71.2833         1           1
# 2         1       3    1    1   7.9250         0           0
# 3         1       1    1    2  53.1000         0           1
# 4         0       3    0    2   8.0500         0           0

# %%
df['FareBand'] = pd.qcut(df['Fare'], 4)
df[['FareBand', 'Survived']].groupby(['FareBand'], as_index=False).mean().sort_values(by='FareBand', ascending=True)
# Out:
#           FareBand  Survived
# 0   (-0.001, 7.91]  0.197309
# 1   (7.91, 14.454]  0.303571
# 2   (14.454, 31.0]  0.454955
# 3  (31.0, 512.329]  0.581081

# %%
df.loc[ df['Fare'] <= 7.91, 'Fare'] = 0
df.loc[(df['Fare'] > 7.91) & (df['Fare'] <= 14.454), 'Fare'] = 1
df.loc[(df['Fare'] > 14.454) & (df['Fare'] <= 31), 'Fare']   = 2
df.loc[ df['Fare'] > 31, 'Fare'] = 3
df['Fare'] = df['Fare'].astype(int)
   
df.head(10)
# Out:
#    Survived  Pclass  Sex  Age  Fare  Embarked  IsNotAlone
# 0         0       3    0    1     0         0           1
# 1         1       1    1    2     0         1           1
# 2         1       3    1    1     0         0           0
# 3         1       1    1    2     0         0           1
# 4         0       3    0    2     0         0           0
# 5         0       3    0    1     0         2           0
# 6         0       1    0    3     0         0           0
# 7         0       3    0    0     0         0           1
# 8         1       3    1    1     0         0           1
# 9         1       2    1    0     0         1           1

# %%
X = df.drop("Survived", axis=1)
Y = df["Survived"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.1, random_state = 42, stratify = Y )

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
lr.score(x_train, y_train)
# Out:
# 0.7952559300873908

# %%
lr.score(x_test, y_test)
# Out:
# 0.7666666666666667

# %%
svc = SVC()
svc.fit(x_train, y_train)
svc.score(x_train, y_train)
# Out:
# 0.815230961298377

# %%
svc.score(x_test, y_test)
# Out:
# 0.8

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_train, y_train)
knn.score(x_train, y_train)
# Out:
# 0.8039950062421972

# %%
knn.score(x_test, y_test)
# Out:
# 0.7888888888888889

# %%
perceptron = Perceptron()
perceptron.fit(x_train, y_train)
perceptron.score(x_train, y_train)
# Out:
# 0.7215980024968789

# %%
perceptron.score(x_test, y_test)
# Out:
# 0.7333333333333333

# %%
gaussian = GaussianNB()
gaussian.fit(x_train, y_train)
gaussian.score(x_train, y_train)
# Out:
# 0.784019975031211

# %%
gaussian.score(x_test, y_test)
# Out:
# 0.7777777777777778

# %%
linear_svc = LinearSVC()
linear_svc.fit(x_train, y_train)
linear_svc.score(x_train, y_train)
# Out:
# 0.7990012484394506

# %%
linear_svc.score(x_test, y_test)
# Out:
# 0.7666666666666667

# %%
sgd = SGDClassifier()
sgd.fit(x_train, y_train)
sgd.score(x_train, y_train)
# Out:
# 0.7615480649188514

# %%
sgd.score(x_test, y_test)
# Out:
# 0.7444444444444445

# %%
decision_tree = DecisionTreeClassifier(max_depth = 8, max_leaf_nodes = 14)
decision_tree.fit(x_train, y_train)
decision_tree.score(x_train, y_train)
# Out:
# 0.8314606741573034

# %%
decision_tree.score(x_test, y_test)
# Out:
# 0.8

# %%
from sklearn import tree

# %%
plt.figure(figsize = (15,20))
tree.plot_tree(decision_tree)
# Out:
# [Text(428.46428571428567, 996.6, 'X[1] <= 0.5\ngini = 0.473\nsamples = 801\nvalue = [494, 307]'),
#  Text(219.2142857142857, 815.4000000000001, 'X[0] <= 1.5\ngini = 0.303\nsamples = 520\nvalue = [423, 97]'),
#  Text(79.71428571428571, 634.2, 'X[2] <= 0.5\ngini = 0.456\nsamples = 105\nvalue = [68, 37]'),
#  Text(39.857142857142854, 453.0, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(119.57142857142856, 453.0, 'X[2] <= 2.5\ngini = 0.444\nsamples = 102\nvalue = [68, 34]'),
#  Text(79.71428571428571, 271.79999999999995, 'gini = 0.466\nsamples = 73\nvalue = [46, 27]'),
#  Text(159.42857142857142, 271.79999999999995, 'gini = 0.366\nsamples = 29\nvalue = [22, 7]'),
#  Text(358.71428571428567, 634.2, 'X[2] <= 0.5\ngini = 0.247\nsamples = 415\nvalue = [355, 60]'),
#  Text(279.0, 453.0, 'X[0] <= 2.5\ngini = 0.48\nsamples = 45\nvalue = [27, 18]'),
#  Text(239.1428571428571, 271.79999999999995, 'X[5] <= 0.5\ngini = 0.298\nsamples = 11\nvalue = [2, 9]'),
#  Text(199.28571428571428, 90.59999999999991, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(279.0, 90.59999999999991, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(318.85714285714283, 271.79999999999995, 'gini = 0.389\nsamples = 34\nvalue = [25, 9]'),
#  Text(438.4285714285714, 453.0, 'X[2] <= 1.5\ngini = 0.201\nsamples = 370\nvalue = [328, 42]'),
#  Text(398.57142857142856, 271.79999999999995, 'gini = 0.233\nsamples = 275\nvalue = [238, 37]'),
#  Text(478.2857142857142, 271.79999999999995, 'gini = 0.1\nsamples = 95\nvalue = [90, 5]'),
#  Text(637.7142857142857, 815.4000000000001, 'X[0] <= 2.5\ngini = 0.378\nsamples = 281\nvalue = [71, 210]'),
#  Text(597.8571428571428, 634.2, 'gini = 0.087\nsamples = 153\nvalue = [7, 146]'),
#  Text(677.5714285714286, 634.2, 'X[4] <= 0.5\ngini = 0.5\nsamples = 128\nvalue = [64, 64]'),
#  Text(597.8571428571428, 453.0, 'X[2] <= 2.5\ngini = 0.473\nsamples = 78\nvalue = [48, 30]'),
#  Text(558.0, 271.79999999999995, 'gini = 0.47\nsamples = 77\nvalue = [48, 29]'),
#  Text(637.7142857142857, 271.79999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(757.2857142857142, 453.0, 'X[2] <= 1.5\ngini = 0.435\nsamples = 50\nvalue = [16, 34]'),
#  Text(717.4285714285713, 271.79999999999995, 'X[2] <= 0.5\ngini = 0.413\nsamples = 48\nvalue = [14, 34]'),
#  Text(677.5714285714286, 90.59999999999991, 'gini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(757.2857142857142, 90.59999999999991, 'gini = 0.451\nsamples = 35\nvalue = [12, 23]'),
#  Text(797.1428571428571, 271.79999999999995, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(x_train, y_train)
random_forest.score(x_train, y_train)
# Out:
# 0.8339575530586767

# %%
random_forest.score(x_test, y_test)
# Out:
# 0.7888888888888889

# %%
from sklearn.pipeline import Pipeline

# %%
random_state = 42

# %%
n_jobs = -1
# LogisticRegression
pipe_lr = Pipeline([('lr', LogisticRegression(random_state=random_state, n_jobs=n_jobs, max_iter=500))])
# RandomForestClassifier
pipe_rf = Pipeline([('rf', RandomForestClassifier(random_state=random_state, oob_score=True, n_jobs=n_jobs))])
# DecisionTreeClassifier
pipe_dt = Pipeline([('dt', DecisionTreeClassifier(random_state=random_state, max_features='auto'))])
# BaggingClassifier

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# %%
'''Set parameters for Grid Search '''
# set number 
cv = StratifiedKFold(shuffle=True, n_splits=5, random_state=random_state)
# set for LogisticRegression
grid_params_lr = [{
                'lr__penalty': ['l2'],
                'lr__C': [0.3, 0.6, 0.7],
                'lr__solver': ['sag']
                }]
# set for RandomForestClassifier
grid_params_rf = [{
                'rf__criterion': ['entropy'],
                'rf__min_samples_leaf': [80, 100],
                'rf__max_depth': [25, 27],
                'rf__min_samples_split': [3, 5],
                'rf__n_estimators' : [60, 70]
                }]

# set for DecisionTreeClassifier
grid_params_dt = [{
                'dt__max_depth': [8, 10],
                'dt__min_samples_leaf': [1, 3, 5, 7]
                  }]

# %%
'''Grid search objects'''
# for LogisticRegression
gs_lr = GridSearchCV(pipe_lr, param_grid=grid_params_lr,
                     scoring='accuracy', cv=cv) 
# for RandomForestClassifier
gs_rf = GridSearchCV(pipe_rf, param_grid=grid_params_rf,
                     scoring='accuracy', cv=cv)

# for DecisionTreeClassifier
gs_dt = GridSearchCV(pipe_dt, param_grid=grid_params_dt,
                     scoring='accuracy', cv=cv)

# %%
look_for = [gs_lr, gs_rf, gs_dt]
# dict for later use 
model_dict = {0:'Logistic_reg', 1:'RandomForest', 2:'DesionTree'}

# %%
enumerate(look_for)

# %%
import time

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# %%
''' Function to iterate over models and obtain results'''
# set empty dicts and list
result_acc = {}
result_auc = {}
models = []

for index, model in enumerate(look_for):
        start = time.time()
        print()
        print('+++++++ Start New Model ++++++++++++++++++++++')
        print('Estimator is {}'.format(model_dict[index]))
        model.fit(x_train, y_train)
        print('---------------------------------------------')
        print('best params {}'.format(model.best_params_))
        print('best score is {}'.format(model.best_score_))
        auc = roc_auc_score(y_test, model.predict_proba(x_test)[:,1])
        print('---------------------------------------------')
        print('ROC_AUC is {} and accuracy rate is {}'.format(auc, model.score(x_test, y_test)))
        end = time.time()
        print('It lasted for {} sec'.format(round(end - start, 3)))
        print('++++++++ End Model +++++++++++++++++++++++++++')
        print()
        print()
        models.append(model.best_estimator_)
        result_acc[index] = model.best_score_
        result_auc[index] = auc
# Out:
# +++++++ Start New Model ++++++++++++++++++++++
# Estimator is Logistic_reg
# ---------------------------------------------
# best params {'lr__C': 0.3, 'lr__penalty': 'l2', 'lr__solver': 'sag'}
# best score is 0.7939829192546582
# ---------------------------------------------
# ROC_AUC is 0.8314285714285715 and accuracy rate is 0.7666666666666667
# It lasted for 27.78 sec
# ++++++++ End Model +++++++++++++++++++++++++++
#
#
#
# +++++++ Start New Model ++++++++++++++++++++++
# Estimator is RandomForest
# ---------------------------------------------
# best params {'rf__criterion': 'entropy', 'rf__max_depth': 25, 'rf__min_samples_leaf': 100, 'rf__min_samples_split': 3, 'rf__n_estimators': 70}
# best score is 0.7852717391304348
# ---------------------------------------------
# ROC_AUC is 0.8241558441558441 and accuracy rate is 0.7444444444444445
# It lasted for 24.88 sec
# ++++++++ End Model +++++++++++++++++++++++++++
#
#
#
# +++++++ Start New Model ++++++++++++++++++++++
# Estimator is DesionTree
# ---------------------------------------------
# best params {'dt__max_depth': 8, 'dt__min_samples_leaf': 5}
# best score is 0.8164673913043478
# ---------------------------------------------
# ROC_AUC is 0.8615584415584415 and accuracy rate is 0.7777777777777778
# It lasted for 0.489 sec
# ++++++++ End Model +++++++++++++++++++++++++++

# %%
""" Model performance during Grid Search """
pd.DataFrame(list(zip(model_dict.values(), result_acc.values(), result_auc.values())), \
                  columns=['Model', 'Accuracy_rate','Roc_auc_rate'])
# Out:
#           Model  Accuracy_rate  Roc_auc_rate
# 0  Logistic_reg       0.793983      0.831429
# 1  RandomForest       0.785272      0.824156
# 2    DesionTree       0.816467      0.861558

# %%
from tqdm import tqdm

# %%
def graph(model, x_train, y_train):
    obb = []
    est = list(range(5, 200, 5))
    for i in tqdm(est):
        random_forest = model(n_estimators=i, criterion='entropy', random_state=11, oob_score=True, n_jobs=-1, \
                           max_depth=25, min_samples_leaf=100, min_samples_split=3,)
        random_forest.fit(x_train, y_train)
        obb.append(random_forest.oob_score_)
    display('max oob {} and number of estimators {}'.format(max(obb), est[np.argmax(obb)]))
    plt.plot(est, obb)
    plt.title('model')
    plt.xlabel('number of estimators')
    plt.ylabel('oob score')
    plt.show();
    
graph(RandomForestClassifier, x_train, y_train)
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]C:\Users\Muhammad Hazim\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:540: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\Muhammad Hazim\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:544: RuntimeWarning: invalid value encountered in true_divide
#   decision = (predictions[k] /
#   3%|▎         | 1/39 [00:00<00:08,  4.48it/s]C:\Users\Muhammad Hazim\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:540: UserWarning: Some inputs do not have OOB scores. This probably means too few trees were used to compute any reliable oob estimates.
#   warn("Some inputs do not have OOB scores. "
# C:\Users\Muhammad Hazim\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:544: RuntimeWarning: invalid value encountered in true_divide
#   decision = (predictions[k] /
# 100%|██████████| 39/39 [00:18<00:00,  2.12it/s]
# 'max oob 0.784019975031211 and number of estimators 120'

# %%
import plotly.graph_objs as go

# %%
''' Build graph for ROC_AUC '''

fpr, tpr, threshold = roc_curve(y_test, models[1].predict_proba(x_test)[:,1])
                                        
trace0 = go.Scatter(
    x=fpr,
    y=tpr,
    text=threshold,
    fill='tozeroy',
    name='ROC Curve')

trace1 = go.Scatter(
    x=[0,1],
    y=[0,1],
    line={'color': 'red', 'width': 1, 'dash': 'dash'},
    name='Baseline')

data = [trace0, trace1]

layout = go.Layout(
    title='ROC Curve',
    xaxis={'title': 'False Positive Rate'},
    yaxis={'title': 'True Positive Rate'})

fig = go.Figure(data, layout)
fig.show();
# Out:
# <div>                            <div id="decb449e-f2bb-4c51-8d41-49b9e761ed2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("decb449e-f2bb-4c51-8d41-49b9e761ed2e")) {                    Plotly.newPlot(                        "decb449e-f2bb-4c51-8d41-49b9e761ed2e",                        [{"fill": "tozeroy", "name": "ROC Curve", "text": [1.62867554567916, 0.6286755456791601, 0.6208810960037111, 0.6194329052710638, 0.5551677575988929, 0.5495452035281343, 0.5474527684901082, 0.5459251171907965, 0.5294101583810141, 0.5258885076157198, 0.5218051627822522, 0.4720578675347509, 0.46669080011031716, 0.4375696348463779, 0.42832699443828165, 0.42319034613970286, 0.39091112837680697, 0.3816684879687107, 0.3784943283545427, 0.36659471859626347, 0.3191630739380438, 0.31244828855320234, 0.3099204335299476, 0.3032056481451061, 0.2958502916676364, 0.2918122793796292, 0.29071157979810835, 0.23535553423429495, 0.23075421917839306], "type": "scatter", "x": [0.0, 0.01818181818181818, 0.01818181818181818, 0.01818181818181818, 0.01818181818181818, 0.03636363636363636, 0.03636363636363636, 0.03636363636363636, 0.05454545454545454, 0.14545454545454545, 0.14545454545454545, 0.16363636363636364, 0.18181818181818182, 0.18181818181818182, 0.2, 0.21818181818181817, 0.23636363636363636, 0.2727272727272727, 0.2909090909090909, 0.34545454545454546, 0.34545454545454546, 0.41818181818181815, 0.43636363636363634, 0.4727272727272727, 0.6181818181818182, 0.6545454545454545, 0.6909090909090909, 0.7454545454545455, 1.0], "y": [0.0, 0.02857142857142857, 0.08571428571428572, 0.17142857142857143, 0.2571428571428571, 0.2857142857142857, 0.37142857142857144, 0.42857142857142855, 0.45714285714285713, 0.4857142857142857, 0.5714285714285714, 0.6285714285714286, 0.6571428571428571, 0.6857142857142857, 0.6857142857142857, 0.7428571428571429, 0.7714285714285715, 0.7714285714285715, 0.8, 0.8, 0.8285714285714286, 0.8857142857142857, 0.8857142857142857, 0.9142857142857143, 0.9428571428571428, 0.9714285714285714, 0.9714285714285714, 0.9714285714285714, 1.0]}, {"line": {"color": "red", "dash": "dash", "width": 1}, "name": "Baseline", "type": "scatter", "x": [0, 1], "y": [0, 1]}],                        {"template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"ou ...

# %%
def build_feature_importance(model, x_train, y_train):
    
    models = RandomForestClassifier(criterion='entropy', random_state=42, oob_score=True, n_jobs=-1, \
                           max_depth=25, min_samples_leaf=100, min_samples_split=3, n_estimators=70)
    models.fit(x_train, y_train)
    data = pd.DataFrame(models.feature_importances_, x_train.columns, columns=["feature"])
    data = data.sort_values(by='feature', ascending=False).reset_index()
    plt.figure(figsize=[6,6])
    sns.barplot(x='index', y='feature', data=data[:10], palette="Blues_d")
    plt.title('Feature inportance of Random Forest after Grid Search')
    plt.xticks(rotation=45)
    plt.show();
    
build_feature_importance(RandomForestClassifier, x_train, y_train)

# %%
models[1]
# Out:
# Pipeline(steps=[('rf',
#                  RandomForestClassifier(criterion='entropy', max_depth=25,
#                                         min_samples_leaf=100,
#                                         min_samples_split=3, n_estimators=70,
#                                         n_jobs=-1, oob_score=True,
#                                         random_state=42))])
